# %%
from nn_reg import kfold, estimator, X, Y, cross_val_score,date_extractor
# Out:
# Using TensorFlow backend.

# %%
results = cross_val_score(estimator, X, Y, cv=kfold)

# %%
print(" Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
#  Results: 2249.39 (1556.14) MSE

# %%
import numpy as np
import matplotlib.pyplot as plt
xf = np.linspace(0,len(Y),len(Y))
plt.plot(xf,Y)

# %%
plt.grid()
plt.show()

# %%
plt.plot(xf[2400:],Y[2400:])
plt.grid()
plt.show()

# %%
plt.plot(xf[2176:2206],Y[2176:2206])

# %%
plt.grid()
plt.show()
